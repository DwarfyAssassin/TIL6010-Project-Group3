# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Data import

# %%
vk_data = pd.read_csv("data/vehicle-kilometres_data.csv", sep=";", index_col="ID")
vk_meta = pd.read_csv("data/vehicle-kilometres_typ_meta.csv", sep=";", skiprows=1, index_col="Key")

vehicle_type = vk_data["TypesOfVehicle"].array.copy()
for i in range(len(vehicle_type)):
    vehicle_type[i] = vk_meta.loc[vehicle_type[i], "Title"]
    
vk_data["TypesOfVehicle_text"] = vehicle_type

cols = vk_data.columns.tolist()
cols = cols[0:1] + cols[-1:] + cols[1:-1]
vk_data = vk_data[cols]

display(vk_data)
# Out:
#     TypesOfVehicle   TypesOfVehicle_text   Periods  \
# ID
# 0          A018928  Total motor vehicles  1990JJ00
# 1          A018928  Total motor vehicles  1991JJ00
# 2          A018928  Total motor vehicles  1992JJ00
# 3          A018928  Total motor vehicles  1993JJ00
# 4          A018928  Total motor vehicles  1994JJ00
# ..             ...                   ...       ...
# 212        A018940                   Bus  2016JJ00
# 213        A018940                   Bus  2017JJ00
# 214        A018940                   Bus  2018JJ00
# 215        A018940                   Bus  2019JJ00
# 216        A018940                   Bus  2020JJ00
#
#      TotalKilometresInTheNetherlands_1 KilometresByDutchVehicles_2  \
# ID
# 0                              96353.0                     91990.0
# 1                              96465.0                     91998.0
# 2                             101215.0                     96576.0
# 3                             101037.0                     96352.0
# 4                             102798.0                     97977.0
# ..                                 ...                         ...
# 212                              611.3                           .
# 213                              654.5                           .
# 214                              664.8                           .
# 215                              638.7                           .
# 216                              507.7                           .
#
#     KilometresByForeignVehicles_3  TotalKilometresByDutchVehicles_4  \
# ID
# 0                          4365.0                          102045.0
# 1                          4465.0                          104089.0
# 2                          4639.0                          108434.0
# 3                          4685.0                          109636.0
# 4                          4820.0                          112477.0
# ..                            ...                               ...
# 212                             .                             656.7
# 213                             .                             695.6
# 214                             .                             706.4
# 215                             .                             684.4
# 216                             .                             523.2
#
#     KilometresInTheNetherlands_5 KilometresAbroad_6
# ID
# 0                        91990.0            10056.0
# 1                        91998.0            12090.0
# 2                        96576.0            11859.0
# 3                        96352.0            13283.0
# 4                        97977.0            14498.0
# ..                           ...                ...
# 212                            .                  .
# 213                            .                  .
# 214                            .                  .
# 215                            .                  .
# 216                            .                  .
#
# [217 rows x 9 columns]

# %%
ems_data = pd.read_csv("data/emissions_data.csv", sep=";", index_col="ID")
ems_source_meta = pd.read_csv("data/emissions_source_meta.csv", sep=";", skiprows=1, index_col="Key")
ems_emission_meta = pd.read_csv("data/emissions_emission_meta.csv", sep=";", skiprows=1, index_col="Key")

sources = ems_data["Sources"].array.copy()
emissions = ems_data["Emissions"].array.copy()
for i in range(len(sources)):
    sources[i] = ems_source_meta.loc[sources[i], "Title"]
    emissions[i] = ems_emission_meta.loc[emissions[i], "Title"]
    
ems_data["Sources_text"] = sources
ems_data["Emissions_text"] = emissions

cols = ems_data.columns.tolist()
cols = cols[0:1] + cols[-2:-1] + cols[1:2] + cols[-1:] + cols[2:-2]
ems_data = ems_data[cols]


display(ems_data)
# Out:
#       Sources                     Sources_text Emissions  \
# ID
# 0     A025421             Total mobile sources   A044109
# 1     A025421             Total mobile sources   A044109
# 2     A025421             Total mobile sources   A044109
# 3     A025421             Total mobile sources   A044109
# 4     A025421             Total mobile sources   A044109
# ...       ...                              ...       ...
# 7387  A025433  Mobile machinery, other sectors   A044113
# 7388  A025433  Mobile machinery, other sectors   A044113
# 7389  A025433  Mobile machinery, other sectors   A044113
# 7390  A025433  Mobile machinery, other sectors   A044113
# 7391  A025433  Mobile machinery, other sectors   A044113
#
#                  Emissions_text   Periods  EmissionsDutchTerritory_1
# ID
# 0          Carbon dioxide (CO2)  1990JJ00                    33400.0
# 1          Carbon dioxide (CO2)  1991JJ00                    33300.0
# 2          Carbon dioxide (CO2)  1992JJ00                    34600.0
# 3          Carbon dioxide (CO2)  1993JJ00                    34800.0
# 4          Carbon dioxide (CO2)  1994JJ00                    35400.0
# ...                         ...       ...                        ...
# 7387  PM10 (Particulate matter)  2017JJ00                        0.2
# 7388  PM10 (Particulate matter)  2018JJ00                        0.2
# 7389  PM10 (Particulate matter)  2019JJ00                        0.2
# 7390  PM10 (Particulate matter)  2020JJ00                        0.2
# 7391  PM10 (Particulate matter)  2021JJ00                        0.2
#
# [7392 rows x 6 columns]
